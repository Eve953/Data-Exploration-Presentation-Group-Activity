# %%
import pandas as pd

# %%
df = pd.read_csv("imdb_top_movies_1980_2026.csv")

# %%
df = df.drop(columns="original_title")

# %%
df
# Out:
#           imdb_id                     title  year  runtime_minutes  \
# 0       tt0111161  The Shawshank Redemption  1994            142.0
# 1       tt0468569           The Dark Knight  2008            152.0
# 2       tt1375666                 Inception  2010            148.0
# 3       tt0137523                Fight Club  1999            139.0
# 4       tt0816692              Interstellar  2014            169.0
# ...           ...                       ...   ...              ...
# 16247   tt3544218                   Belgica  2016            127.0
# 16248   tt0101733    Dil Hai Ki Manta Nahin  1991            154.0
# 16249  tt10994688                 The Binge  2020             98.0
# 16250   tt0263743               Billionaire  1987             96.0
# 16251   tt1921078          Saint Petersburg  2010            120.0
#
#                         genres  average_rating  num_votes  \
# 0                        Drama             9.3    3182733
# ...

# %%
df.isna().sum()
# Out:
# imdb_id            0
# title              0
# year               0
# runtime_minutes    1
# genres             6
# average_rating     0
# num_votes          0
# imdb_url           0
# dtype: int64

# %%
df.dropna()
# Out:
#           imdb_id                     title  year  runtime_minutes  \
# 0       tt0111161  The Shawshank Redemption  1994            142.0
# 1       tt0468569           The Dark Knight  2008            152.0
# 2       tt1375666                 Inception  2010            148.0
# 3       tt0137523                Fight Club  1999            139.0
# 4       tt0816692              Interstellar  2014            169.0
# ...           ...                       ...   ...              ...
# 16247   tt3544218                   Belgica  2016            127.0
# 16248   tt0101733    Dil Hai Ki Manta Nahin  1991            154.0
# 16249  tt10994688                 The Binge  2020             98.0
# 16250   tt0263743               Billionaire  1987             96.0
# 16251   tt1921078          Saint Petersburg  2010            120.0
#
#                         genres  average_rating  num_votes  \
# 0                        Drama             9.3    3182733
# ...

# %% [markdown]
# Potential Questions:
# - most popular genres
# - does length of movie affect its rating
# - which year had the longest movies
